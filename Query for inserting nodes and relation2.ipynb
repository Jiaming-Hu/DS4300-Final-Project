# %%
import pandas as pd
from neo4j import GraphDatabase

# %%
result = pd.read_csv("cleaned_result.csv")
result.head(5)
# Out:
#    index  id                                               name   brand  \
# 0      0   1  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 1      1   1  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 2      2   1  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 3      3   1  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 4      4   1  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
#
#                                           categories manufacturer  rating  \
# 0  Electronics,iPad & Tablets,All Tablets,Fire Ta...       Amazon     5.0
# 1  Electronics,iPad & Tablets,All Tablets,Fire Ta...       Amazon     5.0
# 2  Electronics,iPad & Tablets,All Tablets,Fire Ta...       Amazon     5.0
# 3  Electronics,iPad & Tablets,All Tablets,Fire Ta...       Amazon     4.0
# 4  Electronics,iPad & Tablets,All Tablets,Fire Ta...       Amazon     5.0
#
#                                                 text   username  age
# 0  This product so far has not disappointed. My c...    Adapter   60
# 1  great for beginner or experienced person. Boug...     truman   48
# 2  Inexpensive tablet for him to use and learn on...      DaveZ   28
# 3  I've had my Fire HD 8 two weeks now and I love...     Shacks   48
# 4  I bought this for my grand daughter when she c...  explore42   31

# %%
class Neo4jConnection:
    
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, parameters=None, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response

# %%
# make connection to the database
conn = Neo4jConnection(uri = "neo4j://localhost:7687",
                       user = "neo4j",              
                       #pwd = "Hjm123456"
                      pwd = 'Anni,0710')

# %%
#clear database
def clear(conn):
    conn.query('match(n) detach delete n')

# %%
# Adds user nodes
def add_users():
    user_df = pd.read_csv("user.csv")
    
    query = '''
    UNWIND $rows AS row
    MERGE (u:User {username: row.username, age: row.age})
    '''
    return conn.query(query, parameters = {'rows': user_df.to_dict('records')})

# %%
# Adds product nodes and the relation: user reviews product to the Neo4j graph.
def add_products():
    product_df = pd.read_csv("product.csv")
    
    query = '''
    UNWIND $rows AS row
    MERGE (p:Product {id: row.id, name: row.name, brand:row.brand, manufacturer:row.manufacturer})
    '''
    return conn.query(query, parameters = {'rows': product_df.to_dict('records')})

# %%
# Add relation between user and product: user reviews product.
def add_user_product_relation(dataframe):
    
    query = '''
    UNWIND $rows as row
    MATCH (u: User {username: row.username})
    MATCH (p:Product {id: row.id})
    MERGE (u)-[:Reviews {id:row.index, rating:row.rating, text:row.text}]->(p)
    '''
    return conn.query(query, parameters = {'rows': dataframe.to_dict('records')})

# %%
#Adds category nodes to the Neo4j graph.
def add_categories():
    
    buffer_category_lists = []
    unique_category = []
    
    category_lists = list(result["categories"])
        
    buffer_category_lists = [string.split(",") for string in category_lists]
    for i in buffer_category_lists:
        for j in i:
            unique_category.append(j)
    
    # get unique category list
    unique_category = list(set(unique_category))
    
    for category in unique_category:
        c = '"' + category +'"'
        query = ''' 
        create(c:Category {category: 
        ''' + c + '''})'''
        conn.query(query)

# %%
def add_product_categories_relation(dataframe):
    query = '''
    UNWIND $rows as row
    UNWIND row.categories AS category_name
    MATCH (p:Product {id: row.id})
    MATCH (c:Category {category: category_name})
    MERGE (p)-[:IN_CATEGORY]->(c)
   '''
    return conn.query(query, parameters = {'rows':dataframe.to_dict('records')})

# %%
#construct graph
clear(conn)
# set constrain to nodes so that they won't repeatly added 
# conn.query('CREATE CONSTRAINT User IF NOT EXISTS ON (u:User) ASSERT u.username IS UNIQUE')
# conn.query('CREATE CONSTRAINT Product IF NOT EXISTS ON (p:Product) ASSERT p.id IS UNIQUE')
# conn.query('CREATE CONSTRAINT Category IF NOT EXISTS ON (c:Category) ASSERT c.category IS UNIQUE')

add_products()
print('product finished')
add_categories()
print('category finished')
add_users()
print('user finished')
add_user_product_relation(result)
print('review finished')
add_product_categories_relation(result)
print('in_category relation finished')
# add_products(result.head(300))
# add_users(result.head(300))
# Out:
# product finished
# category finished
# Query failed: {code: Neo.ClientError.Schema.ConstraintValidationFailed} {message: Node(135809) already exists with label `User` and property `username` = 'johnbgood'}
# user finished
# review finished

# %%
def add_product_categories_relation2(dataframe):
    for index,row in dataframe.iterrows():
        categories = list(row[4].split(","))
        product_id = "% s" % row[1]
        for c in categories:
            query = '''
            MATCH (p:Product {id: '''+ product_id+'''})
            MATCH (c:Category {category: "''' + c + '''"})
            MERGE (p)-[:IN]->(c)
           '''
            conn.query(query)

# %%
add_product_categories_relation2(result.head())
print('in_category relation finished')
# Out:
# in_category relation finished

# %%
conn.query('''MATCH(u:User)
return u.username''')
# Out:
# []

# %%
conn.query('''MATCH(u:User)-[r:Reviews]->(p:Product)
with u,count(p) as cou
where cou>1
return u.username, cou''')
# Out:
# []

# %%
conn.query('match (p:Product) -[:IN]->(c:Category) return p,c')
# Out:
# [<Record p=<Node id=134149 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta', 'id': 1, 'brand': 'Amazon', 'manufacturer': 'Amazon'}> c=<Node id=134268 labels=frozenset({'Category'}) properties={'category': 'Computers & Tablets'}>>,
#  <Record p=<Node id=134149 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta', 'id': 1, 'brand': 'Amazon', 'manufacturer': 'Amazon'}> c=<Node id=134447 labels=frozenset({'Category'}) properties={'category': 'Tablets'}>>,
#  <Record p=<Node id=134149 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta', 'id': 1, 'brand': 'Amazon', 'manufacturer': 'Amazon'}> c=<Node id=134443 labels=frozenset({'Category'}) properties={'category': 'Fire Tablets'}>>,
#  <Record p=<Node id=134149 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta', 'id': 1, 'brand': 'Amazon', 'manufacturer': 'Amazon'}> c=<Node id=134249 labels=frozenset({'Category'}) properties={'category': 'All Tablets'}>>,
#  <Record p=<Node id=134149 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta', 'id': 1, 'brand': 'Amazon', 'manufacturer': 'Amazon'}> c=<Node id=134253 labels=frozenset({'Category'}) properties={'category': 'iPad & Tablets'}>>,
#  <Record p=<Node id=134149 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta', 'id': 1, 'brand': 'Amazon', 'manufacturer': 'Amazon'}> c=<Node id=134505 labels=frozenset({'Category'}) properties={'category': 'Electronics'}>>]

# %%
#build content-based filtering query
def cbf_query(username):
    username = '"' + username+ '"'
    query = '''MATCH(u:User{username:'''+ username +'''})-[:Reviews]->(p:Product)-[:IN]->(c:Category)<-[:IN]-(p2:Product)
WHERE NOT EXISTS ((u)-[:Reviews]->(p2))
WITH p, p2, COUNT(c) AS intersection
MATCH (p)-[:IN]->(pc:Category)
WITH p, p2, intersection, COLLECT(pc.category) AS s1
MATCH (p2)-[:IN]->(p2c:Category)
WITH p, p2, s1, intersection, COLLECT(p2c.category) AS s2
WITH p, p2, intersection, s1+[x IN s2 WHERE NOT x IN s1] AS union, s1, s2
RETURN p.name as Userproduct, p2.name as Recommendate, s1 as UserProductCategory, s2 as RecommendateProductCategory, ((1.0*intersection)/SIZE(union)) AS jaccard ORDER BY jaccard DESC'''
    return query

# %%
print(cbf_query('Adapter'))
# Out:
# MATCH(u:User{username:"Adapter"})-[:Reviews]->(p:Product)-[:IN]->(c:Category)<-[:IN]-(p2:Product)
# WHERE NOT EXISTS ((u)-[:Reviews]->(p2))
# WITH p, p2, COUNT(c) AS intersection
# MATCH (p)-[:IN]->(pc:Category)
# WITH p, p2, intersection, COLLECT(pc.category) AS s1
# MATCH (p2)-[:IN]->(p2c:Category)
# WITH p, p2, s1, intersection, COLLECT(p2c.category) AS s2
# WITH p, p2, intersection, s1+[x IN s2 WHERE NOT x IN s1] AS union, s1, s2
# RETURN p.name as Userproduct, p2.name as Recommendate, s1 as UserProductCategory, s2 as RecommendateProductCategory, ((1.0*intersection)/SIZE(union)) AS jaccard ORDER BY jaccard DESC

# %%
conn.query('match (n) return n')
# Out:
# [<Record n=<Node id=134149 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta', 'id': 1, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134150 labels=frozenset({'Product'}) properties={'name': 'Kindle Oasis E-reader with Leather Charging Cover - Merlot, 6 High-Resolution Display (300 ppi), Wi-Fi - Includes Special Offers,,', 'id': 2, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134151 labels=frozenset({'Product'}) properties={'name': 'Amazon Kindle Lighted Leather Cover,,,\r\nAmazon Kindle Lighted Leather Cover,,,', 'id': 3, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134152 labels=frozenset({'Product'}) properties={'name': 'Kindle Keyboard,,,\r\nKindle Keyboard,,,', 'id': 4, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134153 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Special Offers, Magenta', 'id': 5, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134154 labels=frozenset({'Product'}) properties={'name': 'Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Tangerine - with Special Offers,', 'id': 6, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134155 labels=frozenset({'Product'}) properties={'name': 'Amazon 5W USB Official OEM Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,\r\nAmazon 5W USB Official OEM Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,', 'id': 7, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134156 labels=frozenset({'Product'}) properties={'name': 'Amazon Kindle Fire Hd (3rd Generation) 8gb,,,\r\nAmazon Kindle Fire Hd (3rd Generation) 8gb,,,', 'id': 8, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134157 labels=frozenset({'Product'}) properties={'name': 'Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Magenta', 'id': 9, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134158 labels=frozenset({'Product'}) properties={'name': 'Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Magenta', 'id': 10, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134159 labels=frozenset({'Product'}) properties={'name': 'Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet Wifi 16 Gb Blue,,,', 'id': 11, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134160 labels=frozenset({'Product'}) properties={'name': 'Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet Wifi 16 Gb Blue,,,', 'id': 12, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134161 labels=frozenset({'Product'}) properties={'name': 'Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet Wifi 16 Gb Blue,,,', 'id': 13, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134162 labels=frozenset({'Product'}) properties={'name': 'Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet Wifi 16 Gb Blue,,,', 'id': 14, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134163 labels=frozenset({'Product'}) properties={'name': 'Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet Wifi 16 Gb Blue,,,', 'id': 15, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134164 labels=frozenset({'Product'}) properties={'name': 'Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet Wifi 16 Gb Blue,,,', 'id': 16, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134165 labels=frozenset({'Product'}) properties={'name': 'Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Green Kid-Proof Case', 'id': 17, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134166 labels=frozenset({'Product'}) properties={'name': 'Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Green Kid-Proof Case', 'id': 18, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134167 labels=frozenset({'Product'}) properties={'name': 'Amazon Kindle Paperwhite - eBook reader - 4 GB - 6 monochrome Paperwhite - touchscreen - Wi-Fi - black,,,', 'id': 19, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134168 labels=frozenset({'Product'}) properties={'name': 'Kindle Voyage E-reader, 6 High-Resolution Display (300 ppi) with Adaptive Built-in Light, PagePress Sensors, Wi-Fi - Includes Special Offers,', 'id': 20, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134169 labels=frozenset({'Product'}) properties={'name': 'Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black', 'id': 21, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134170 labels=frozenset({'Product'}) properties={'name': 'Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black', 'id': 22, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134171 labels=frozenset({'Product'}) properties={'name': 'Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black', 'id': 23, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134172 labels=frozenset({'Product'}) properties={'name': 'Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black', 'id': 24, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134173 labels=frozenset({'Product'}) properties={'name': 'Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black', 'id': 25, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134174 labels=frozenset({'Product'}) properties={'name': 'Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black', 'id': 26, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134175 labels=frozenset({'Product'}) properties={'name': 'Echo (White),,,\r\nEcho (White),,,', 'id': 27, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134176 labels=frozenset({'Product'}) properties={'name': 'Echo (White),,,\r\nEcho (White),,,', 'id': 28, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134177 labels=frozenset({'Product'}) properties={'name': 'Echo (White),,,\r\nEcho (White),,,', 'id': 29, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134178 labels=frozenset({'Product'}) properties={'name': 'Echo (White),,,\r\nEcho (White),,,', 'id': 30, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134179 labels=frozenset({'Product'}) properties={'name': nan, 'id': 31, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134180 labels=frozenset({'Product'}) properties={'name': nan, 'id': 32, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134181 labels=frozenset({'Product'}) properties={'name': nan, 'id': 33, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134182 labels=frozenset({'Product'}) properties={'name': nan, 'id': 34, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134183 labels=frozenset({'Product'}) properties={'name': nan, 'id': 35, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134184 labels=frozenset({'Product'}) properties={'name': nan, 'id': 36, 'brand': 'Amazon Fire', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134185 labels=frozenset({'Product'}) properties={'name': nan, 'id': 37, 'brand': 'Amazon Echo', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134186 labels=frozenset({'Product'}) properties={'name': nan, 'id': 38, 'brand': 'Amazon Coco T', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134187 labels=frozenset({'Product'}) properties={'name': nan, 'id': 39, 'brand': 'Amazon Fire Tv', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134188 labels=frozenset({'Product'}) properties={'name': nan, 'id': 40, 'brand': 'Amazon Digital Services Inc.', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134189 labels=frozenset({'Product'}) properties={'name': nan, 'id': 41, 'brand': 'Amazon', 'manufacturer': 'Amazon Digital Services, Inc'}>>,
#  <Record n=<Node id=134190 labels=frozenset({'Product'}) properties={'name': nan, 'id': 42, 'brand': 'Amazon', 'manufacturer': 'Amazon Digital Services, Inc'}>>,
#  <Record n=<Node id=134191 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics AAA Performance Alkaline Batteries (36 Count)', 'id': 43, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134192 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics Nylon CD/DVD Binder (400 Capacity)', 'id': 44, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134193 labels=frozenset({'Product'}) properties={'name': 'Amazon Echo Show - Black', 'id': 45, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134194 labels=frozenset({'Product'}) properties={'name': 'Echo Spot Pair Kit (Black)', 'id': 46, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134195 labels=frozenset({'Product'}) properties={'name': 'Fire TV Stick Streaming Media Player Pair Kit', 'id': 47, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134196 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics AA Performance Alkaline Batteries (48 Count) - Packaging May Vary', 'id': 48, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134197 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics Ventilated Adjustable Laptop Stand', 'id': 49, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134198 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics Backpack for Laptops up to 17-inches', 'id': 50, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134199 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics 11.6-Inch Laptop Sleeve', 'id': 51, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134200 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics 15.6-Inch Laptop and Tablet Bag', 'id': 52, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134201 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics External Hard Drive Case', 'id': 53, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134202 labels=frozenset({'Product'}) properties={'name': 'Expanding Accordion File Folder Plastic Portable Document Organizer Letter Size', 'id': 54, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134203 labels=frozenset({'Product'}) properties={'name': 'Cat Litter Box Covered Tray Kitten Extra Large Enclosed Hooded Hidden Toilet', 'id': 55, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134204 labels=frozenset({'Product'}) properties={'name': 'Kindle PowerFast International Charging Kit (for accelerated charging in over 200 countries)', 'id': 56, 'brand': 'Amazon', 'manufacturer': 'Amazon Digital Services'}>>,
#  <Record n=<Node id=134205 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics Silicone Hot Handle Cover/Holder - Red', 'id': 57, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134206 labels=frozenset({'Product'}) properties={'name': 'Amazon Kindle Charger Power Adapter Wall Charger And Usb Cable Micro Usb Cord', 'id': 58, 'brand': 'Amazon', 'manufacturer': 'Amazon Digital Services'}>>,
#  <Record n=<Node id=134207 labels=frozenset({'Product'}) properties={'name': 'Amazon Echo (1st Generationcertified) Color:White Free Shipping', 'id': 59, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134208 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics USB 3.0 Cable - A-Male to B-Male - 6 Feet (1.8 Meters)', 'id': 60, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134209 labels=frozenset({'Product'}) properties={'name': 'Two Door Top Load Pet Kennel Travel Crate Dog Cat Pet Cage Carrier Box Tray 23"', 'id': 61, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134210 labels=frozenset({'Product'}) properties={'name': 'Oem Amazon Kindle Power Usb Adapter Wall Travel Charger Fire/dx/+micro Usb Cable', 'id': 62, 'brand': 'Amazon', 'manufacturer': 'Amazon Digital Services'}>>,
#  <Record n=<Node id=134211 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics 16-Gauge Speaker Wire - 100 Feet', 'id': 63, 'brand': 'Amazonbasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134212 labels=frozenset({'Product'}) properties={'name': 'Amazon Echo (2nd Generation) Smart Assistant Oak Finish Priority Shipping', 'id': 64, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134213 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics Nespresso Pod Storage Drawer - 50 Capsule Capacity', 'id': 65, 'brand': 'AmazonBasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134214 labels=frozenset({'Product'}) properties={'name': 'Certified Refurbished Amazon Echo', 'id': 66, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134215 labels=frozenset({'Product'}) properties={'name': 'All-new Echo (2nd Generation) with improved sound, powered by Dolby, and a new design Walnut Finish', 'id': 67, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134216 labels=frozenset({'Product'}) properties={'name': 'Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Pink Kid-Proof Case', 'id': 68, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134217 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Special Offers, Black', 'id': 69, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134218 labels=frozenset({'Product'}) properties={'name': 'All-New Fire 7 Tablet with Alexa, 7" Display, 8 GB - Marine Blue', 'id': 70, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134219 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Blue', 'id': 71, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134220 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Special Offers, Blue', 'id': 72, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134221 labels=frozenset({'Product'}) properties={'name': 'Amazon Fire HD 8 with Alexa (8" HD Display Tablet)', 'id': 73, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134222 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics Single-Door Folding Metal Dog Crate - Large (42x28x30 Inches)', 'id': 74, 'brand': 'AmazonBasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134223 labels=frozenset({'Product'}) properties={'name': 'All-New Kindle Oasis E-reader - 7 High-Resolution Display (300 ppi), Waterproof, Built-In Audible, 32 GB, Wi-Fi + Free Cellular Connectivity', 'id': 75, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134224 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics Double-Door Folding Metal Dog Crate - Medium (36x23x25 Inches)', 'id': 76, 'brand': 'AmazonBasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134225 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Pink Kid-Proof Case', 'id': 77, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134226 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Blue Kid-Proof Case', 'id': 78, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134227 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Marine Blue - with Special Offers', 'id': 79, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134228 labels=frozenset({'Product'}) properties={'name': 'All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Marine Blue - with Special Offers', 'id': 80, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134229 labels=frozenset({'Product'}) properties={'name': 'Fire Tablet with Alexa, 7 Display, 16 GB, Magenta - with Special Offers', 'id': 81, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134230 labels=frozenset({'Product'}) properties={'name': 'Echo Dot (Previous generation)', 'id': 82, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134231 labels=frozenset({'Product'}) properties={'name': 'Kindle Oasis E-reader with Leather Charging Cover - Walnut, 6 High-Resolution Display (300 ppi), Wi-Fi - Includes Special Offers', 'id': 83, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134232 labels=frozenset({'Product'}) properties={'name': 'All-New Kindle Oasis E-reader - 7 High-Resolution Display (300 ppi), Waterproof, Built-In Audible, 8 GB, Wi-Fi - Includes Special Offers', 'id': 84, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134233 labels=frozenset({'Product'}) properties={'name': 'Kindle E-reader - White, 6 Glare-Free Touchscreen Display, Wi-Fi - Includes Special Offers', 'id': 85, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134234 labels=frozenset({'Product'}) properties={'name': 'Amazon Fire TV Gaming Edition Streaming Media Player', 'id': 86, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134235 labels=frozenset({'Product'}) properties={'name': 'All-New Kindle Oasis E-reader - 7 High-Resolution Display (300 ppi), Waterproof, Built-In Audible, 32 GB, Wi-Fi - Includes Special Offers', 'id': 87, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134236 labels=frozenset({'Product'}) properties={'name': 'AmazonBasics Bluetooth Keyboard for Android Devices - Black', 'id': 88, 'brand': 'AmazonBasics', 'manufacturer': 'AmazonBasics'}>>,
#  <Record n=<Node id=134237 labels=frozenset({'Product'}) properties={'name': 'Amazon Kindle Replacement Power Adapter (Fits Latest Generation Kindle and Kindle DX) For shipment in the U.S only', 'id': 89, 'brand': 'Amazon', 'manufacturer': 'Amazon.com'}>>,
#  <Record n=<Node id=134238 labels=frozenset({'Product'}) properties={'name': 'Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen', 'id': 90, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134239 labels=frozenset({'Product'}) properties={'name': 'Amazon Fire TV with 4K Ultra HD and Alexa Voice Remote (Pendant Design) | Streaming Media Player', 'id': 91, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134240 labels=frozenset({'Product'}) properties={'name': 'Amazon - Echo Plus w/ Built-In Hub - Silver', 'id': 92, 'brand': 'Amazon', 'manufacturer': 'Amazon'}>>,
#  <Record n=<Node id=134241 labels=frozenset({'Category'}) properties={'category': 'File Folders & Accessories'}>>,
#  <Record n=<Node id=134242 labels=frozenset({'Category'}) properties={'category': 'Streaming Devices'}>>,
#  <Record n=<Node id=134243 labels=frozenset({'Category'}) properties={'category': 'Kitchen Dining Features'}>>,
#  <Record n=<Node id=134244 labels=frozenset({'Category'}) properties={'category': 'Computer Accessories & Peripherals'}>>,
#  <Record n=<Node id=134245 labels=frozenset({'Category'}) properties={'category': 'Cases & Covers'}>>,
#  <Record n=<Node id=134246 labels=frozenset({'Category'}) properties={'category': 'Blank Audio/Video Media'}>>,
#  <Record n=<Node id=134247 labels=frozenset({'Category'}) properties={'category': ' Video & Audio Accessories'}>>,
#  <Record n=<Node id=134248 labels=frozenset({'Category'}) properties={'category': 'Expanding File Jackets Pockets'}>>,
#  <Record n=<Node id=134249 labels=frozenset({'Category'}) properties={'category': 'All Tablets'}>>,
#  <Record n=<Node id=134250 labels=frozenset({'Category'}) properties={'category': 'Android Tablets'}>>,
#  <Record n=<Node id=134251 labels=frozenset({'Category'}) properties={'category': 'Camera Batteries'}>>,
#  <Record n=<Node id=134252 labels=frozenset({'Category'}) properties={'category': 'Networking'}>>,
#  <Record n=<Node id=134253 labels=frozenset({'Category'}) properties={'category': 'iPad & Tablets'}>>,
#  <Record n=<Node id=134254 labels=frozenset({'Category'}) properties={'category': 'Filing Products'}>>,
#  <Record n=<Node id=134255 labels=frozenset({'Category'}) properties={'category': 'MP3 Player Accessories'}>>,
#  <Record n=<Node id=134256 labels=frozenset({'Category'}) properties={'category': 'Why Keep Them Waiting Prime Free Two-Day Shipping'}>>,
#  <Record n=<Node id=134257 labels=frozenset({'Category'}) properties={'category': 'Tablets for Kids'}>>,
#  <Record n=<Node id=134258 labels=frozenset({'Category'}) properties={'category': 'Remote Controls'}>>,
#  <Record n=<Node id=134259 labels=frozenset({'Category'}) properties={'category': 'Expanding File Jackets & Pockets'}>>,
#  <Record n=<Node id=134260 labels=frozenset({'Category'}) properties={'category': 'Portable Audio'}>>,
#  <Record n=<Node id=134261 labels=frozenset({'Category'}) properties={'category': 'Amazon Devices & Accessories'}>>,
#  <Record n=<Node id=134262 labels=frozenset({'Category'}) properties={'category': 'Home'}>>,
#  <Record n=<Node id=134263 labels=frozenset({'Category'}) properties={'category': 'Amazon Echo'}>>,
#  <Record n=<Node id=134264 labels=frozenset({'Category'}) properties={'category': 'Filing'}>>,
#  <Record n=<Node id=134265 labels=frozenset({'Category'}) properties={'category': 'TVs Entertainment'}>>,
#  <Record n=<Node id=134266 labels=frozenset({'Category'}) properties={'category': 'Home & Furniture Clearance'}>>,
#  <Record n=<Node id=134267 labels=frozenset({'Category'}) properties={'category': 'Keyboards'}>>,
#  <Record n=<Node id=134268 labels=frozenset({'Category'}) properties={'category': 'Computers & Tablets'}>>,
#  <Record n=<Node id=134269 labels=frozenset({'Category'}) properties={'category': 'Cell Phone Batteries & Power'}>>,
#  <Record n=<Node id=134270 labels=frozenset({'Category'}) properties={'category': ' Audio Player Accessories'}>>,
#  <Record n=<Node id=134271 labels=frozenset({'Category'}) properties={'category': 'Computer Accessories'}>>,
#  <Record n=<Node id=134272 labels=frozenset({'Category'}) properties={'category': 'Household Supplies'}>>,
#  <Record n=<Node id=134273 labels=frozenset({'Category'}) properties={'category': 'Other Multipurpose Batteries'}>>,
#  <Record n=<Node id=134274 labels=frozenset({'Category'}) properties={'category': 'Speaker Cables'}>>,
#  <Record n=<Node id=134275 labels=frozenset({'Category'}) properties={'category': 'Amazon Echo Accessories'}>>,
#  <Record n=<Node id=134276 labels=frozenset({'Category'}) properties={'category': 'Home & Garden'}>>,
#  <Record n=<Node id=134277 labels=frozenset({'Category'}) properties={'category': 'Kindle Touch (4th Generation) Accessories'}>>,
#  <Record n=<Node id=134278 labels=frozenset({'Category'}) properties={'category': 'Smart Speakers'}>>,
#  <Record n=<Node id=134279 labels=frozenset({'Category'}) properties={'category': 'Expanding Files'}>>,
#  <Record n=<Node id=134280 labels=frozenset({'Category'}) properties={'category': 'Robot Check'}>>,
#  <Record n=<Node id=134281 labels=frozenset({'Category'}) properties={'category': 'iPod'}>>,
#  <Record n=<Node id=134282 labels=frozenset({'Category'}) properties={'category': 'Smart Hub & Kits'}>>,
#  <Record n=<Node id=134283 labels=frozenset({'Category'}) properties={'category': 'Featured Brands'}>>,
#  <Record n=<Node id=134284 labels=frozenset({'Category'}) properties={'category': 'Bags'}>>,
#  <Record n=<Node id=134285 labels=frozenset({'Category'}) properties={'category': 'Kitchen & Dining'}>>,
#  <Record n=<Node id=134286 labels=frozenset({'Category'}) properties={'category': 'Laptop Cases & Bags'}>>,
#  <Record n=<Node id=134287 labels=frozenset({'Category'}) properties={'category': 'See more File Pocket Expanding Folder Office Organizer ...'}>>,
#  <Record n=<Node id=134288 labels=frozenset({'Category'}) properties={'category': 'Consumer Electronics'}>>,
#  <Record n=<Node id=134289 labels=frozenset({'Category'}) properties={'category': 'Kitchen'}>>,
#  <Record n=<Node id=134290 labels=frozenset({'Category'}) properties={'category': 'Used:Tablets'}>>,
#  <Record n=<Node id=134291 labels=frozenset({'Category'}) properties={'category': 'All Streaming Media Players'}>>,
#  <Record n=<Node id=134292 labels=frozenset({'Category'}) properties={'category': 'Home Kitchen Features'}>>,
#  <Record n=<Node id=134293 labels=frozenset({'Category'}) properties={'category': 'Kindle Fire (2nd Generation) Accessories'}>>,
#  <Record n=<Node id=134294 labels=frozenset({'Category'}) properties={'category': 'Home Automation'}>>,
#  <Record n=<Node id=134295 labels=frozenset({'Category'}) properties={'category': 'Kindle Accessories'}>>,
#  <Record n=<Node id=134296 labels=frozenset({'Category'}) properties={'category': 'Fire TV Accessories'}>>,
#  <Record n=<Node id=134297 labels=frozenset({'Category'}) properties={'category': 'Office'}>>,
#  <Record n=<Node id=134298 labels=frozenset({'Category'}) properties={'category': 'Amazon Book Reader Accessory'}>>,
#  <Record n=<Node id=134299 labels=frozenset({'Category'}) properties={'category': 'Power & Speaker Wire'}>>,
#  <Record n=<Node id=134300 labels=frozenset({'Category'}) properties={'category': 'Backpacks'}>>,
#  <Record n=<Node id=134301 labels=frozenset({'Category'}) properties={'category': 'Vehicle Electronics & GPS'}>>,
#  <Record n=<Node id=134302 labels=frozenset({'Category'}) properties={'category': 'All Bluetooth & Wireless Speakers'}>>,
#  <Record n=<Node id=134303 labels=frozenset({'Category'}) properties={'category': 'Video Games'}>>,
#  <Record n=<Node id=134304 labels=frozenset({'Category'}) properties={'category': 'Smart Home Automation'}>>,
#  <Record n=<Node id=134305 labels=frozenset({'Category'}) properties={'category': 'Office & School Supplies'}>>,
#  <Record n=<Node id=134306 labels=frozenset({'Category'}) properties={'category': "Kids' Tablets"}>>,
#  <Record n=<Node id=134307 labels=frozenset({'Category'}) properties={'category': 'On To College'}>>,
#  <Record n=<Node id=134308 labels=frozenset({'Category'}) properties={'category': 'Lotions'}>>,
#  <Record n=<Node id=134309 labels=frozenset({'Category'}) properties={'category': 'Laptop & Desktop Accessories'}>>,
#  <Record n=<Node id=134310 labels=frozenset({'Category'}) properties={'category': 'Carrying Case Or Bag'}>>,
#  <Record n=<Node id=134311 labels=frozenset({'Category'}) properties={'category': 'Disc Storage Wallets'}>>,
#  <Record n=<Node id=134312 labels=frozenset({'Category'}) properties={'category': ' Storage & Blank Media'}>>,
#  <Record n=<Node id=134313 labels=frozenset({'Category'}) properties={'category': ' DVD & Blu-ray Discs'}>>,
#  <Record n=<Node id=134314 labels=frozenset({'Category'}) properties={'category': 'Hard Drive Bags Cases'}>>,
#  <Record n=<Node id=134315 labels=frozenset({'Category'}) properties={'category': 'computers'}>>,
#  <Record n=<Node id=134316 labels=frozenset({'Category'}) properties={'category': 'Books & Magazines'}>>,
#  <Record n=<Node id=134317 labels=frozenset({'Category'}) properties={'category': 'Holiday Shop'}>>,
#  <Record n=<Node id=134318 labels=frozenset({'Category'}) properties={'category': 'Chargers & Sync Cables'}>>,
#  <Record n=<Node id=134319 labels=frozenset({'Category'}) properties={'category': 'Book Accessories'}>>,
#  <Record n=<Node id=134320 labels=frozenset({'Category'}) properties={'category': 'Wired Headsets & Speakers'}>>,
#  <Record n=<Node id=134321 labels=frozenset({'Category'}) properties={'category': 'Cable Or Adapter'}>>,
#  <Record n=<Node id=134322 labels=frozenset({'Category'}) properties={'category': 'Covers'}>>,
#  <Record n=<Node id=134323 labels=frozenset({'Category'}) properties={'category': 'Consoles'}>>,
#  <Record n=<Node id=134324 labels=frozenset({'Category'}) properties={'category': 'See more Amazon Echo Show Smart Assistant - White'}>>,
#  <Record n=<Node id=134325 labels=frozenset({'Category'}) properties={'category': 'College Tvs & Home Theater'}>>,
#  <Record n=<Node id=134326 labels=frozenset({'Category'}) properties={'category': 'Dogs'}>>,
#  <Record n=<Node id=134327 labels=frozenset({'Category'}) properties={'category': ' Tech Toys'}>>,
#  <Record n=<Node id=134328 labels=frozenset({'Category'}) properties={'category': 'Home & Kitchen'}>>,
#  <Record n=<Node id=134329 labels=frozenset({'Category'}) properties={'category': 'Health'}>>,
#  <Record n=<Node id=134330 labels=frozenset({'Category'}) properties={'category': 'Top Rated'}>>,
#  <Record n=<Node id=134331 labels=frozenset({'Category'}) properties={'category': 'Power Adapters Cables'}>>,
#  <Record n=<Node id=134332 labels=frozenset({'Category'}) properties={'category': 'Tablet Accessories'}>>,
#  <Record n=<Node id=134333 labels=frozenset({'Category'}) properties={'category': 'Amazon SMP'}>>,
#  <Record n=<Node id=134334 labels=frozenset({'Category'}) properties={'category': 'Crates & Kennels'}>>,
#  <Record n=<Node id=134335 labels=frozenset({'Category'}) properties={'category': ' Global Wireless) Accessories'}>>,
#  <Record n=<Node id=134336 labels=frozenset({'Category'}) properties={'category': 'Health and Beauty'}>>,
#  <Record n=<Node id=134337 labels=frozenset({'Category'}) properties={'category': 'Computers & Laptops'}>>,
#  <Record n=<Node id=134338 labels=frozenset({'Category'}) properties={'category': 'Speakers'}>>,
#  <Record n=<Node id=134339 labels=frozenset({'Category'}) properties={'category': 'Kids & Family'}>>,
#  <Record n=<Node id=134340 labels=frozenset({'Category'}) properties={'category': 'Top Cat Supplies'}>>,
#  <Record n=<Node id=134341 labels=frozenset({'Category'}) properties={'category': 'Computer Add On'}>>,
#  <Record n=<Node id=134342 labels=frozenset({'Category'}) properties={'category': 'Pet Supplies'}>>,
#  <Record n=<Node id=134343 labels=frozenset({'Category'}) properties={'category': 'College Ipads & Tablets'}>>,
#  <Record n=<Node id=134344 labels=frozenset({'Category'}) properties={'category': 'See more Amazon Fire TV with Alexa Voice Remote Digital...'}>>,
#  <Record n=<Node id=134345 labels=frozenset({'Category'}) properties={'category': 'Kitchen Storage & Organization'}>>,
#  <Record n=<Node id=134346 labels=frozenset({'Category'}) properties={'category': 'Expanding Wallets'}>>,
#  <Record n=<Node id=134347 labels=frozenset({'Category'}) properties={'category': 'Smart Home & Home Automation Devices'}>>,
#  <Record n=<Node id=134348 labels=frozenset({'Category'}) properties={'category': ' Cases & Sleeves'}>>,
#  <Record n=<Node id=134349 labels=frozenset({'Category'}) properties={'category': 'Chargers & Adapters'}>>,
#  <Record n=<Node id=134350 labels=frozenset({'Category'}) properties={'category': 'Speaker Systems'}>>,
#  <Record n=<Node id=134351 labels=frozenset({'Category'}) properties={'category': 'Home & Outdoors'}>>,
#  <Record n=<Node id=134352 labels=frozenset({'Category'}) properties={'category': 'Computers & Accessories'}>>,
#  <Record n=<Node id=134353 labels=frozenset({'Category'}) properties={'category': 'Tablet Cases Covers'}>>,
#  <Record n=<Node id=134354 labels=frozenset({'Category'}) properties={'category': 'Media Cases & Storage'}>>,
#  <Record n=<Node id=134355 labels=frozenset({'Category'}) properties={'category': 'Smart Hubs & Wireless Routers'}>>,
#  <Record n=<Node id=134356 labels=frozenset({'Category'}) properties={'category': ' Hubs & Accessories'}>>,
#  <Record n=<Node id=134357 labels=frozenset({'Category'}) properties={'category': 'Home Audio'}>>,
#  <Record n=<Node id=134358 labels=frozenset({'Category'}) properties={'category': 'Custom Stores'}>>,
#  <Record n=<Node id=134359 labels=frozenset({'Category'}) properties={'category': 'Standard Litter Boxes'}>>,
#  <Record n=<Node id=134360 labels=frozenset({'Category'}) properties={'category': 'Audio Cables'}>>,
#  <Record n=<Node id=134361 labels=frozenset({'Category'}) properties={'category': 'Crates Kennels'}>>,
#  <Record n=<Node id=134362 labels=frozenset({'Category'}) properties={'category': 'Wireless Speakers'}>>,
#  <Record n=<Node id=134363 labels=frozenset({'Category'}) properties={'category': 'Office Furniture Lighting'}>>,
#  <Record n=<Node id=134364 labels=frozenset({'Category'}) properties={'category': 'Car Audio & Video Installation'}>>,
#  <Record n=<Node id=134365 labels=frozenset({'Category'}) properties={'category': 'Fire (5th Generation) Accessories'}>>,
#  <Record n=<Node id=134366 labels=frozenset({'Category'}) properties={'category': 'iPads Tablets'}>>,
#  <Record n=<Node id=134367 labels=frozenset({'Category'}) properties={'category': 'Laptop Computer Stands'}>>,
#  <Record n=<Node id=134368 labels=frozenset({'Category'}) properties={'category': 'Personal Computer'}>>,
#  <Record n=<Node id=134369 labels=frozenset({'Category'}) properties={'category': 'Moisturizers'}>>,
#  <Record n=<Node id=134370 labels=frozenset({'Category'}) properties={'category': 'Hard Drive Pouches'}>>,
#  <Record n=<Node id=134371 labels=frozenset({'Category'}) properties={'category': 'eReaders'}>>,
#  <Record n=<Node id=134372 labels=frozenset({'Category'}) properties={'category': 'Audio'}>>,
#  <Record n=<Node id=134373 labels=frozenset({'Category'}) properties={'category': 'Alarms & Sensors'}>>,
#  <Record n=<Node id=134374 labels=frozenset({'Category'}) properties={'category': 'Audio & Video Components'}>>,
#  <Record n=<Node id=134375 labels=frozenset({'Category'}) properties={'category': 'Amazon Home'}>>,
#  <Record n=<Node id=134376 labels=frozenset({'Category'}) properties={'category': 'all electronics'}>>,
#  <Record n=<Node id=134377 labels=frozenset({'Category'}) properties={'category': 'Accessories & Supplies'}>>,
#  <Record n=<Node id=134378 labels=frozenset({'Category'}) properties={'category': 'Kindle DX (2nd Generation'}>>,
#  <Record n=<Node id=134379 labels=frozenset({'Category'}) properties={'category': 'Speakers & Audio Systems'}>>,
#  <Record n=<Node id=134380 labels=frozenset({'Category'}) properties={'category': 'Tablet & E-Reader Accessories'}>>,
#  <Record n=<Node id=134381 labels=frozenset({'Category'}) properties={'category': 'Hubs & Controllers'}>>,
#  <Record n=<Node id=134382 labels=frozenset({'Category'}) properties={'category': 'Crate Training'}>>,
#  <Record n=<Node id=134383 labels=frozenset({'Category'}) properties={'category': 'Kitchen & Dining Features'}>>,
#  <Record n=<Node id=134384 labels=frozenset({'Category'}) properties={'category': 'Cables'}>>,
#  <Record n=<Node id=134385 labels=frozenset({'Category'}) properties={'category': 'Amazon Device Accessories'}>>,
#  <Record n=<Node id=134386 labels=frozenset({'Category'}) properties={'category': 'Home Audio & Home Theater'}>>,
#  <Record n=<Node id=134387 labels=frozenset({'Category'}) properties={'category': 'mazon.co.uk'}>>,
#  <Record n=<Node id=134388 labels=frozenset({'Category'}) properties={'category': 'Stands'}>>,
#  <Record n=<Node id=134389 labels=frozenset({'Category'}) properties={'category': 'Smead'}>>,
#  <Record n=<Node id=134390 labels=frozenset({'Category'}) properties={'category': 'Business & Industrial'}>>,
#  <Record n=<Node id=134391 labels=frozenset({'Category'}) properties={'category': 'Cases'}>>,
#  <Record n=<Node id=134392 labels=frozenset({'Category'}) properties={'category': 'Office Products'}>>,
#  <Record n=<Node id=134393 labels=frozenset({'Category'}) properties={'category': 'Computer Speakers'}>>,
#  <Record n=<Node id=134394 labels=frozenset({'Category'}) properties={'category': 'See more AmazonBasics Double Door Folding Metal Dog Cra...'}>>,
#  <Record n=<Node id=134395 labels=frozenset({'Category'}) properties={'category': 'Software & Books'}>>,
#  <Record n=<Node id=134396 labels=frozenset({'Category'}) properties={'category': 'File & Folder Accessories'}>>,
#  <Record n=<Node id=134397 labels=frozenset({'Category'}) properties={'category': 'Messenger Bags'}>>,
#  <Record n=<Node id=134398 labels=frozenset({'Category'}) properties={'category': 'See more Amazon Echo Spot Smart Assistant - Black'}>>,
#  <Record n=<Node id=134399 labels=frozenset({'Category'}) properties={'category': 'Portable Audio & Electronics'}>>,
#  <Record n=<Node id=134400 labels=frozenset({'Category'}) properties={'category': 'Kindle Store'}>>,
#  <Record n=<Node id=134401 labels=frozenset({'Category'}) properties={'category': 'Bluetooth & Wireless Speakers'}>>,
#  <Record n=<Node id=134402 labels=frozenset({'Category'}) properties={'category': 'Streaming Media Players'}>>,
#  <Record n=<Node id=134403 labels=frozenset({'Category'}) properties={'category': 'Kindle Touch (4th Generation) Covers'}>>,
#  <Record n=<Node id=134404 labels=frozenset({'Category'}) properties={'category': 'Electrical'}>>,
#  <Record n=<Node id=134405 labels=frozenset({'Category'}) properties={'category': 'Drive Enclosures & Docks'}>>,
#  <Record n=<Node id=134406 labels=frozenset({'Category'}) properties={'category': 'Other TV'}>>,
#  <Record n=<Node id=134407 labels=frozenset({'Category'}) properties={'category': 'See more Amazon Echo (1st Generation) Smart Assistant -...'}>>,
#  <Record n=<Node id=134408 labels=frozenset({'Category'}) properties={'category': 'Mobile Bluetooth Speakers'}>>,
#  <Record n=<Node id=134409 labels=frozenset({'Category'}) properties={'category': 'New Networking'}>>,
#  <Record n=<Node id=134410 labels=frozenset({'Category'}) properties={'category': 'Surveillance & Smart Home Electronics'}>>,
#  <Record n=<Node id=134411 labels=frozenset({'Category'}) properties={'category': 'Office Furniture & Lighting'}>>,
#  <Record n=<Node id=134412 labels=frozenset({'Category'}) properties={'category': 'Notebook Computer Stands'}>>,
#  <Record n=<Node id=134413 labels=frozenset({'Category'}) properties={'category': 'College Electronics'}>>,
#  <Record n=<Node id=134414 labels=frozenset({'Category'}) properties={'category': 'Hard Drive Accessories'}>>,
#  <Record n=<Node id=134415 labels=frozenset({'Category'}) properties={'category': 'Surveillance'}>>,
#  <Record n=<Node id=134416 labels=frozenset({'Category'}) properties={'category': 'Office Electronics'}>>,
#  <Record n=<Node id=134417 labels=frozenset({'Category'}) properties={'category': ' Stands & Shelves'}>>,
#  <Record n=<Node id=134418 labels=frozenset({'Category'}) properties={'category': 'Dog Supplies'}>>,
#  <Record n=<Node id=134419 labels=frozenset({'Category'}) properties={'category': 'TV'}>>,
#  <Record n=<Node id=134420 labels=frozenset({'Category'}) properties={'category': 'iPad Accessories'}>>,
#  <Record n=<Node id=134421 labels=frozenset({'Category'}) properties={'category': 'Computers/Tablets & Networking'}>>,
#  <Record n=<Node id=134422 labels=frozenset({'Category'}) properties={'category': 'Internet & Media Streamers'}>>,
#  <Record n=<Node id=134423 labels=frozenset({'Category'}) properties={'category': 'Batteries & Chargers'}>>,
#  <Record n=<Node id=134424 labels=frozenset({'Category'}) properties={'category': ' Storage & Binding'}>>,
#  <Record n=<Node id=134425 labels=frozenset({'Category'}) properties={'category': 'Pet Products'}>>,
#  <Record n=<Node id=134426 labels=frozenset({'Category'}) properties={'category': 'Categories'}>>,
#  <Record n=<Node id=134427 labels=frozenset({'Category'}) properties={'category': 'Home Audio & Video Accessories'}>>,
#  <Record n=<Node id=134428 labels=frozenset({'Category'}) properties={'category': 'Digital Device Accessory'}>>,
#  <Record n=<Node id=134429 labels=frozenset({'Category'}) properties={'category': 'Tablet & eBook Reader Accs'}>>,
#  <Record n=<Node id=134430 labels=frozenset({'Category'}) properties={'category': 'Mobile Speakers'}>>,
#  <Record n=<Node id=134431 labels=frozenset({'Category'}) properties={'category': 'eBook Readers & Accessories'}>>,
#  <Record n=<Node id=134432 labels=frozenset({'Category'}) properties={'category': 'Batteries'}>>,
#  <Record n=<Node id=134433 labels=frozenset({'Category'}) properties={'category': 'Amazon Tablet Accessory'}>>,
#  <Record n=<Node id=134434 labels=frozenset({'Category'}) properties={'category': 'Video Devices & TV Tuners'}>>,
#  <Record n=<Node id=134435 labels=frozenset({'Category'}) properties={'category': 'Filing & Organizers'}>>,
#  <Record n=<Node id=134436 labels=frozenset({'Category'}) properties={'category': 'Tablets & E-Readers'}>>,
#  <Record n=<Node id=134437 labels=frozenset({'Category'}) properties={'category': 'Kids Family'}>>,
#  <Record n=<Node id=134438 labels=frozenset({'Category'}) properties={'category': 'Digital Device 4'}>>,
#  <Record n=<Node id=134439 labels=frozenset({'Category'}) properties={'category': ' Video & Home Audio'}>>,
#  <Record n=<Node id=134440 labels=frozenset({'Category'}) properties={'category': 'Portable Computer Accessories'}>>,
#  <Record n=<Node id=134441 labels=frozenset({'Category'}) properties={'category': 'Home Audio Speakers'}>>,
#  <Record n=<Node id=134442 labels=frozenset({'Category'}) properties={'category': 'Computers'}>>,
#  <Record n=<Node id=134443 labels=frozenset({'Category'}) properties={'category': 'Fire Tablets'}>>,
#  <Record n=<Node id=134444 labels=frozenset({'Category'}) properties={'category': 'Household Batteries'}>>,
#  <Record n=<Node id=134445 labels=frozenset({'Category'}) properties={'category': 'Mobile'}>>,
#  <Record n=<Node id=134446 labels=frozenset({'Category'}) properties={'category': 'Kindle (5th Generation) Covers'}>>,
#  <Record n=<Node id=134447 labels=frozenset({'Category'}) properties={'category': 'Tablets'}>>,
#  <Record n=<Node id=134448 labels=frozenset({'Category'}) properties={'category': 'Drives'}>>,
#  <Record n=<Node id=134449 labels=frozenset({'Category'}) properties={'category': 'EBook Readers'}>>,
#  <Record n=<Node id=134450 labels=frozenset({'Category'}) properties={'category': 'Portable Speakers'}>>,
#  <Record n=<Node id=134451 labels=frozenset({'Category'}) properties={'category': 'Amazon Tap'}>>,
#  <Record n=<Node id=134452 labels=frozenset({'Category'}) properties={'category': 'Camera & Photo'}>>,
#  <Record n=<Node id=134453 labels=frozenset({'Category'}) properties={'category': 'Carriers & Totes'}>>,
#  <Record n=<Node id=134454 labels=frozenset({'Category'}) properties={'category': 'Used:Computers Accessories'}>>,
#  <Record n=<Node id=134455 labels=frozenset({'Category'}) properties={'category': 'Virtual Assistant Speakers'}>>,
#  <Record n=<Node id=134456 labels=frozenset({'Category'}) properties={'category': 'Smart Hubs'}>>,
#  <Record n=<Node id=134457 labels=frozenset({'Category'}) properties={'category': 'Portable Bluetooth Speakers'}>>,
#  <Record n=<Node id=134458 labels=frozenset({'Category'}) properties={'category': 'AA'}>>,
#  <Record n=<Node id=134459 labels=frozenset({'Category'}) properties={'category': ' Holders & Car Mounts'}>>,
#  <Record n=<Node id=134460 labels=frozenset({'Category'}) properties={'category': 'Litter Boxes'}>>,
#  <Record n=<Node id=134461 labels=frozenset({'Category'}) properties={'category': 'Office Supplies'}>>,
#  <Record n=<Node id=134462 labels=frozenset({'Category'}) properties={'category': 'Abis Electronics'}>>,
#  <Record n=<Node id=134463 labels=frozenset({'Category'}) properties={'category': 'eBook Readers'}>>,
#  <Record n=<Node id=134464 labels=frozenset({'Category'}) properties={'category': 'Cages & Crates'}>>,
#  <Record n=<Node id=134465 labels=frozenset({'Category'}) properties={'category': 'Amazon Book Reader'}>>,
#  <Record n=<Node id=134466 labels=frozenset({'Category'}) properties={'category': 'Fire TV'}>>,
#  <Record n=<Node id=134467 labels=frozenset({'Category'}) properties={'category': 'Beauty'}>>,
#  <Record n=<Node id=134468 labels=frozenset({'Category'}) properties={'category': 'USB Cables'}>>,
#  <Record n=<Node id=134469 labels=frozenset({'Category'}) properties={'category': 'Amazon Tablets'}>>,
#  <Record n=<Node id=134470 labels=frozenset({'Category'}) properties={'category': 'Home Safety & Security'}>>,
#  <Record n=<Node id=134471 labels=frozenset({'Category'}) properties={'category': ' Wi-Fi  3G (Unlocked...'}>>,
#  <Record n=<Node id=134472 labels=frozenset({'Category'}) properties={'category': 'AmazonBasics'}>>,
#  <Record n=<Node id=134473 labels=frozenset({'Category'}) properties={'category': 'Camcorder Batteries'}>>,
#  <Record n=<Node id=134474 labels=frozenset({'Category'}) properties={'category': 'Health & Household'}>>,
#  <Record n=<Node id=134475 labels=frozenset({'Category'}) properties={'category': 'Accessories'}>>,
#  <Record n=<Node id=134476 labels=frozenset({'Category'}) properties={'category': 'Ready Meals'}>>,
#  <Record n=<Node id=134477 labels=frozenset({'Category'}) properties={'category': 'TV & Video'}>>,
#  <Record n=<Node id=134478 labels=frozenset({'Category'}) properties={'category': 'Cell Phone Accessories'}>>,
#  <Record n=<Node id=134479 labels=frozenset({'Category'}) properties={'category': 'Electronics Features'}>>,
#  <Record n=<Node id=134480 labels=frozenset({'Category'}) properties={'category': 'Amazon Ereaders'}>>,
#  <Record n=<Node id=134481 labels=frozenset({'Category'}) properties={'category': 'Office Product'}>>,
#  <Record n=<Node id=134482 labels=frozenset({'Category'}) properties={'category': 'Linens & Textiles'}>>,
#  <Record n=<Node id=134483 labels=frozenset({'Category'}) properties={'category': ' Household & Baby Care'}>>,
#  <Record n=<Node id=134484 labels=frozenset({'Category'}) properties={'category': 'Fire Tablet Accessories'}>>,
#  <Record n=<Node id=134485 labels=frozenset({'Category'}) properties={'category': 'See more Amazon Kindle Fire 5-Feet Micro USB Cable - Wh...'}>>,
#  <Record n=<Node id=134486 labels=frozenset({'Category'}) properties={'category': 'Food Storage'}>>,
#  <Record n=<Node id=134487 labels=frozenset({'Category'}) properties={'category': 'See more AmazonBasics 15.6 Inch Laptop And Tablet Bag -...'}>>,
#  <Record n=<Node id=134488 labels=frozenset({'Category'}) properties={'category': 'Tablets & eBook Readers'}>>,
#  <Record n=<Node id=134489 labels=frozenset({'Category'}) properties={'category': 'See more Amazon Kindle Voyage 4GB'}>>,
#  <Record n=<Node id=134490 labels=frozenset({'Category'}) properties={'category': 'Home & Tools'}>>,
#  <Record n=<Node id=134491 labels=frozenset({'Category'}) properties={'category': 'E-Readers'}>>,
#  <Record n=<Node id=134492 labels=frozenset({'Category'}) properties={'category': 'Compact Radios Stereos'}>>,
#  <Record n=<Node id=134493 labels=frozenset({'Category'}) properties={'category': ' Mice & Accessories'}>>,
#  <Record n=<Node id=134494 labels=frozenset({'Category'}) properties={'category': 'Virtual Assistant Speakers Displays'}>>,
#  <Record n=<Node id=134495 labels=frozenset({'Category'}) properties={'category': 'Electronic Components'}>>,
#  <Record n=<Node id=134496 labels=frozenset({'Category'}) properties={'category': 'TV & Home Theater'}>>,
#  <Record n=<Node id=134497 labels=frozenset({'Category'}) properties={'category': 'Walmart for Business'}>>,
#  <Record n=<Node id=134498 labels=frozenset({'Category'}) properties={'category': 'See more Amazon Kindle Voyage (Wi-Fi)'}>>,
#  <Record n=<Node id=134499 labels=frozenset({'Category'}) properties={'category': 'Storage & Organization'}>>,
#  <Record n=<Node id=134500 labels=frozenset({'Category'}) properties={'category': 'Sleeves'}>>,
#  <Record n=<Node id=134501 labels=frozenset({'Category'}) properties={'category': 'City Sniffers'}>>,
#  <Record n=<Node id=134502 labels=frozenset({'Category'}) properties={'category': 'Home Improvement'}>>,
#  <Record n=<Node id=134503 labels=frozenset({'Category'}) properties={'category': 'All Windows Tablets'}>>,
#  <Record n=<Node id=134504 labels=frozenset({'Category'}) properties={'category': 'Learning Toys'}>>,
#  <Record n=<Node id=134505 labels=frozenset({'Category'}) properties={'category': 'Electronics'}>>,
#  <Record n=<Node id=134506 labels=frozenset({'Category'}) properties={'category': 'Cat Supplies'}>>,
#  <Record n=<Node id=134507 labels=frozenset({'Category'}) properties={'category': 'Audio & Video Accessories'}>>,
#  <Record n=<Node id=134508 labels=frozenset({'Category'}) properties={'category': 'Cases & Bags'}>>,
#  <Record n=<Node id=134509 labels=frozenset({'Category'}) properties={'category': 'Tablets & E-readers'}>>,
#  <Record n=<Node id=134510 labels=frozenset({'Category'}) properties={'category': 'Files & Supplies'}>>,
#  <Record n=<Node id=134511 labels=frozenset({'Category'}) properties={'category': 'Ways To Shop'}>>,
#  <Record n=<Node id=134512 labels=frozenset({'Category'}) properties={'category': 'Home Security'}>>,
#  <Record n=<Node id=134513 labels=frozenset({'Category'}) properties={'category': 'Media Streamers'}>>,
#  <Record n=<Node id=134514 labels=frozenset({'Category'}) properties={'category': 'eReaders & Accessories'}>>,
#  <Record n=<Node id=134515 labels=frozenset({'Category'}) properties={'category': 'Home Theater & Audio'}>>,
#  <Record n=<Node id=134516 labels=frozenset({'Category'}) properties={'category': 'CD'}>>,
#  <Record n=<Node id=134517 labels=frozenset({'Category'}) properties={'category': 'Digital Device 3'}>>,
#  <Record n=<Node id=134518 labels=frozenset({'Category'}) properties={'category': 'Desk Accessories & Workspace Organizers'}>>,
#  <Record n=<Node id=134519 labels=frozenset({'Category'}) properties={'category': 'Home & Kitchen Features'}>>,
#  <Record n=<Node id=134520 labels=frozenset({'Category'}) properties={'category': 'Amazon'}>>,
#  <Record n=<Node id=134521 labels=frozenset({'Category'}) properties={'category': 'Hard-Sided Carriers'}>>,
#  <Record n=<Node id=134522 labels=frozenset({'Category'}) properties={'category': 'MP3 MP4 Player Accessories'}>>,
#  <Record n=<Node id=134523 labels=frozenset({'Category'}) properties={'category': 'Toys'}>>,
#  <Record n=<Node id=134524 labels=frozenset({'Category'}) properties={'category': 'Tablets & eReaders'}>>,
#  <Record n=<Node id=134525 labels=frozenset({'Category'}) properties={'category': 'Kindle (5th Generation) Accessories'}>>,
#  <Record n=<Node id=134526 labels=frozenset({'Category'}) properties={'category': 'Smart Speaker & Hub Accessories'}>>,
#  <Record n=<Node id=134527 labels=frozenset({'Category'}) properties={'category': 'Carriers & Crates'}>>,
#  <Record n=<Node id=134528 labels=frozenset({'Category'}) properties={'category': 'Chargers Adapters'}>>,
#  <Record n=<Node id=134529 labels=frozenset({'Category'}) properties={'category': 'Platforms'}>>,
#  <Record n=<Node id=134530 labels=frozenset({'Category'}) properties={'category': 'Smart Home'}>>,
#  <Record n=<Node id=134531 labels=frozenset({'Category'}) properties={'category': 'Pet Supplies: International Shipping Available'}>>,
#  <Record n=<Node id=134532 labels=frozenset({'Category'}) properties={'category': 'Rice Dishes'}>>,
#  <Record n=<Node id=134533 labels=frozenset({'Category'}) properties={'category': 'Racks & Holders'}>>,
#  <Record n=<Node id=134534 labels=frozenset({'Category'}) properties={'category': 'Portable Audio & Headphones'}>>,
#  <Record n=<Node id=134535 labels=frozenset({'Category'}) properties={'category': 'Kindle Paperwhite Accessories'}>>,
#  <Record n=<Node id=134536 labels=frozenset({'Category'}) properties={'category': 'Smart Home & Connected Living'}>>,
#  <Record n=<Node id=134537 labels=frozenset({'Category'}) properties={'category': 'Back To College'}>>,
#  <Record n=<Node id=134538 labels=frozenset({'Category'}) properties={'category': ' Movies'}>>,
#  <Record n=<Node id=134539 labels=frozenset({'Category'}) properties={'category': ' Garage & Office'}>>,
#  <Record n=<Node id=134540 labels=frozenset({'Category'}) properties={'category': 'Furniture'}>>,
#  <Record n=<Node id=134541 labels=frozenset({'Category'}) properties={'category': 'Oven Mitts & Potholders'}>>,
#  <Record n=<Node id=134542 labels=frozenset({'Category'}) properties={'category': 'Kindle E-Reader Accessories'}>>,
#  <Record n=<Node id=134543 labels=frozenset({'Category'}) properties={'category': 'Computers Features'}>>,
#  <Record n=<Node id=134544 labels=frozenset({'Category'}) properties={'category': 'Audio Docks & Mini Speakers'}>>,
#  <Record n=<Node id=134545 labels=frozenset({'Category'}) properties={'category': 'Office Solutions'}>>,
#  <Record n=<Node id=134546 labels=frozenset({'Category'}) properties={'category': ' Dining & Bar'}>>,
#  <Record n=<Node id=134547 labels=frozenset({'Category'}) properties={'category': 'Cables & Interconnects'}>>,
#  <Record n=<Node id=134548 labels=frozenset({'Category'}) properties={'category': 'Coffee Pod Holders'}>>,
#  <Record n=<Node id=134549 labels=frozenset({'Category'}) properties={'category': 'Bluetooth Speakers'}>>,
#  <Record n=<Node id=134550 labels=frozenset({'Category'}) properties={'category': ' Music'}>>,
#  <Record n=<Node id=134551 labels=frozenset({'Category'}) properties={'category': 'Genuine Tablet Accessories'}>>,
#  <Record n=<Node id=134552 labels=frozenset({'Category'}) properties={'category': 'Voice-Enabled Smart Assistants'}>>,
#  <Record n=<Node id=134553 labels=frozenset({'Category'}) properties={'category': 'Kindle E-readers'}>>,
#  <Record n=<Node id=134554 labels=frozenset({'Category'}) properties={'category': 'Voice Assistants'}>>,
#  <Record n=<Node id=134555 labels=frozenset({'Category'}) properties={'category': 'File Jackets & File Pockets'}>>,
#  <Record n=<Node id=134556 labels=frozenset({'Category'}) properties={'category': 'Media Storage & Organization'}>>,
#  <Record n=<Node id=134557 labels=frozenset({'Category'}) properties={'category': 'Home Office Furniture'}>>,
#  <Record n=<Node id=134558 labels=frozenset({'Category'}) properties={'category': 'Cookware Accessories'}>>,
#  <Record n=<Node id=134559 labels=frozenset({'Category'}) properties={'category': 'Windows Tablets'}>>,
#  <Record n=<Node id=134560 labels=frozenset({'Category'}) properties={'category': 'E-Readers & Accessories'}>>,
#  <Record n=<Node id=134561 labels=frozenset({'Category'}) properties={'category': 'DVD Cases'}>>,
#  <Record n=<Node id=134562 labels=frozenset({'Category'}) properties={'category': 'Computer Components'}>>,
#  <Record n=<Node id=134563 labels=frozenset({'Category'}) properties={'category': 'Cell Phones'}>>,
#  <Record n=<Node id=134564 labels=frozenset({'Category'}) properties={'category': 'Other Computers & Networking'}>>,
#  <Record n=<Node id=134565 labels=frozenset({'Category'}) properties={'category': 'Cables & Chargers'}>>,
#  <Record n=<Node id=134566 labels=frozenset({'Category'}) properties={'category': 'Electronics Deals'}>>,
#  <Record n=<Node id=134567 labels=frozenset({'Category'}) properties={'category': 'Amazon Devices'}>>,
#  <Record n=<Node id=134568 labels=frozenset({'Category'}) properties={'category': 'Stereos'}>>,
#  <Record n=<Node id=134569 labels=frozenset({'Category'}) properties={'category': 'Top Selection from AmazonPets'}>>,
#  <Record n=<Node id=134570 labels=frozenset({'Category'}) properties={'category': 'AAA'}>>,
#  <Record n=<Node id=134571 labels=frozenset({'Category'}) properties={'category': 'Power Adapters'}>>,
#  <Record n=<Node id=134572 labels=frozenset({'Category'}) properties={'category': 'Health Personal Care'}>>,
#  <Record n=<Node id=134573 labels=frozenset({'Category'}) properties={'category': '14701001'}>>,
#  <Record n=<Node id=134574 labels=frozenset({'Category'}) properties={'category': ' Video & Audio Accs'}>>,
#  <Record n=<Node id=134575 labels=frozenset({'Category'}) properties={'category': 'Cookware'}>>,
#  <Record n=<Node id=134576 labels=frozenset({'Category'}) properties={'category': 'MP3 Accessories'}>>,
#  <Record n=<Node id=134577 labels=frozenset({'Category'}) properties={'category': 'Power Adapters & Cables'}>>,
#  <Record n=<Node id=134578 labels=frozenset({'Category'}) properties={'category': 'Clearance'}>>,
#  <Record n=<Node id=134579 labels=frozenset({'Category'}) properties={'category': 'Hard Drive Bags & Cases'}>>,
#  <Record n=<Node id=134580 labels=frozenset({'Category'}) properties={'category': 'Tvs & Home Theater'}>>,
#  <Record n=<Node id=134581 labels=frozenset({'Category'}) properties={'category': 'TVs Entertainment xbqxrzdteyyb'}>>,
#  <Record n=<Node id=134582 labels=frozenset({'Category'}) properties={'category': 'TVs & Electronics'}>>,
#  <Record n=<Node id=134583 labels=frozenset({'Category'}) properties={'category': 'Laptop Accessories'}>>,
#  <Record n=<Node id=134584 labels=frozenset({'Category'}) properties={'category': 'TVs & Home Theater'}>>,
#  <Record n=<Node id=134585 labels=frozenset({'Category'}) properties={'category': 'Frys'}>>,
#  <Record n=<Node id=134586 labels=frozenset({'Category'}) properties={'category': 'Hard Drives & Storage'}>>]

# %%
conn.close()
